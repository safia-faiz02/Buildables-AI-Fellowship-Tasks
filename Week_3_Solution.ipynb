# %% [markdown]
# # 1. Start writing prompts like a pro

# %% [markdown]
# ## **Prompt Engineering Quiz 💡**
#
# ### Question 1 ☑️
# **What is prompting?**
# Answer: The way you give instructions or input to a LLM model.
#
# ### Question 2 ☑️
# **In the following prompt, which part describes the primary task?**
# Prompt: *“Explain how car batteries work using non-technical language that someone without any mechanical knowledge could understand and interpret.”*
# Answer: Explain how car batteries work.
#
# ### Question 3 ☑️
# **When you are using a gen AI tool to create a healthy three-course menu that requires a certain number of calories, which prompting element will ensure the menu is more practical?**
# Answer: Always Be Iterating (ABI) methodology might work better as the better you evaluate and iterate, you'll get a better response from AI tool.
#
# ### Question 4 ☑️
# **Prompting with audio to receive a visual representation is called what?**
# Answer: Multimodal prompting.
#
# ### Question 5 ☑️
# **What does a human-in-the-loop approach to prompting emphasize?**
# Answer: It helps eradicate the errors and hallucinations, and human-in-the-loop ensures clarity in what the user wants.
#
# ### Question 6 ☑️
# **When the initial prompt "Create a dataset" is too broad, what should you do to refine it?**
# Answer: You should use the Task -> Context -> References -> Evaluate -> Iterate framework.

# %% [markdown]
# # 2. Design prompts for everyday work tasks

# %% [markdown]
# ## Exercise: Try It Yourself ❗
# 1. Write down your **to-do list** for today or this week.
#
# ```
# - Complete this notebook task
# - Email a professor
# ```
#
#
# 2. Pick **one task** where AI could help.
#    - Example: "Write a follow-up email to my team"
# `- Email a professor`
# 3. Open your AI tool and **give it this prompt**:
#    - *“Draft a professional, friendly email reminding my team about our weekly meeting.”*
#
# ```
#    Response:
#
#    Subject: Reminder: Weekly Team Meeting
#
# Hi Team,
#
# Just a quick reminder about our weekly meeting scheduled for [day, date, time]. We’ll be discussing [main agenda topics, if any], so please come prepared with any updates or questions.
#
# Looking forward to seeing you all there!
#
# Best,
# [Your Name]
# ```
#
# 4. Review, edit, and use the result ✅

# %% [markdown]
# ## Exercise: Try It Yourself ❗
# 1. Think of an **email you need to write** (e.g., to your team, customers, or a client).
# - Write an email to a professor
# 2. Use the **prompt framework**:
#    - Persona: Who are you?
#    - Context: What’s happening?
#    - Task: What do you want the email to do?
#    - Specificity: Add tone, format, details.
#
# - Persona: Graduate applicant to Algoma University.
# - Context: Professor’s research aligns with your projects; you’ve applied and mentioned him in your SOP.
# - Task: Draft a professional email showing interest in his work, highlighting your achievements/projects, and expressing fit.
# - Specificity: Mention top academic performance, recent AI projects, and eagerness to work under his guidance.
#
# 3. Ask your AI tool to **draft the email**.
#
# Subject: Interest in Your Research and Graduate Application at Algoma University
#
# Dear Professor [Last Name],
#
# I hope this email finds you well. My name is Safia Faiz, and I have applied for admission to the [Program Name, e.g., MSc in Computer Science] program at Algoma University. I am reaching out to express my strong interest in your research and to highlight how my background aligns with your work.
#
# I recently completed my Bachelor’s degree in Computer Systems Engineering at NED University, where I graduated first in my batch with multiple 4.0 GPA semesters. My academic and project work has centered on AI and data-driven systems, including a final year project on image captioning with computer vision. More recently, I developed a RAG-based application for tracking child development milestones, leveraging vector databases, NLP models, and progress analytics. I was especially excited to see how this aligns with your recent research on [insert professor’s specific focus].
#
# I have mentioned your name in my Statement of Purpose as a professor whose guidance I am eager to receive. I believe my academic achievements and hands-on project experience make me a strong fit for contributing to your research group.
#
# It would be an honor to work with you, and I would be grateful if you could kindly review my profile. Thank you for your time and consideration.
#
# Sincerely,
# Safia Faiz
#
# 4. Then, **iterate**:
#    - Change the tone (formal → casual, professional → fun).
#    - Adjust the audience.

# %% [markdown]
# ## Exercise: Try It Yourself ❗
# **Practice Tone & Style Prompting**
# 1. Pick a short text you’ve written (an email, a report, or a social post).
#
# Email i wrote to graduate admissions dept:
#
# Hi Ildiko, I had a query.
# My degree is currently being evaluated by WES, and that's still in the process.
# Also, I am out of the country and can't contact my university in person to email my transcript and degree to Algoma U. Can I be given some time until I receive my evaluation report from WES Canada?
#
#
# 2. Rewrite your prompt to **specify tone and style**.
#    - Example: “Make this LinkedIn post sound **inspirational, like a TED speaker motivating professionals.**”
#
#    change the tone to be professional and straightforward and shorter and to the point that it becomes a one liner only
#
# 3. Run it through your AI tool.
#
# Hi Ildiko, my WES evaluation is still in process and as I am currently abroad, may I have some additional time to submit my transcript and degree to Algoma University?
#
# 4. Iterate: Ask for a new version in a **different tone** (funny, formal, academic, casual).
#
# make it more casual and make it feel like i am talking to an adult but with respect and in a normal way in a witty way not in a formal and strict way
#
# Hi Ildiko, my WES evaluation is still in the works, and since I’m stuck abroad, could I get a bit of extra time to send my transcript and degree to Algoma U?
#
# 5. Compare the results — which version feels most effective for your audience?
#
# one is very casual as if you're talking to a fellow, the other is talking to someone that strictly means business. the difference that i noticed is mainly of tone

# %% [markdown]
# ##  Exercises : Try It Yourself ❗
#
# ### Exercise 1: Icebreakers
#
# Write a prompt asking AI to generate **3 creative icebreakers** for a new teammate who loves basketball and photography.
#
# Persona: I’m a fellow teammate
#
# Context: want to break the ice with a new teammate who loves basketball and photography
#
# Task: write three creative icebreakers
#
# Format: catchy, funny, witty
#
# ### Exercise 2: Product Launch
#
# Imagine you’re launching a **new mobile fitness app** (it can be any product).
# Write a prompt to:
#
# * Define a **6-month launch timeline**.
# * Suggest **3 pre-launch buzz ideas**.
#
# Persona: I'm going to launch a brand new product
#
# Context: it is a shooting game which is similar to pubg, but there are additional features such as creating your own gun skins and creating your own maps where you play
#
# Task: define a 6 month launch timeline, and suggest 3 pre-launch buzz ideas
#
# Format: give me the timeline in bullets and the pre launch ideas should be witty and eye catchy and should add some game elements to them to make them fun
#
# ### Exercise 3: Global Audience Twist
#
# Take your product launch prompt and **iterate** by asking the AI to adjust the ideas for a **global audience**.
#
# Persona: I’m launching a new global multiplayer shooting game.
#
# Context: The game is similar to PUBG but includes additional features: players can design their own gun skins and create custom maps for gameplay.
#
# Task:
#
# Define a 6-month global launch timeline.
#
# Suggest 3 pre-launch buzz ideas that are witty, eye-catching, and incorporate fun gaming elements for a worldwide audience.
#
# Format:
#
# Timeline: Present in bullet points with key milestones.
#
# Pre-launch ideas: Make them engaging, fun, and globally appealing while highlighting game features (gun skin creation, custom maps, multiplayer excitement).

# %% [markdown]
# ## Exercises: Try It Yourself ❗
#
# ### Exercise 1: Project Tracker
#
# Prompt AI to create a **project tracker** with columns: Task, Owner, Deadline, Status.
# Add constraints: Each owner should have no more than 2 active tasks.
#
# ![image.png](data:image/png;base64,...)
#
# Constraint enforcement:
#
# - Each owner (Alice, Bob, Charlie) has no more than 2 active tasks at a time (active = “Not Started” or “In Progress”).
# - New tasks should only be assigned if the owner has fewer than 2 active tasks.
#
# ### Exercise 2: Event Schedule
#
# You’re planning a **3-day conference**. Ask AI to generate a schedule with:
#
# * Columns: Day, Session Title, Speaker, Time.
# * Constraint: No speaker should have more than 1 session per day.
#
# ![image.png](data:image/png;base64,...)
#
# Constraint Check:
#
# - Each speaker has only 1 session per day.
# - Networking/lunch sessions have no assigned speaker.
#
# ### Exercise 3: Team Availability
#
# Write a prompt to generate a **vacation tracker** for 8 employees.
#
# * Columns: Employee, Vacation Start, Vacation End.
# * Constraint: At least 5 employees must be available at all times.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ✅ Reflection Question
#
# How could you use AI to **organize recurring tasks** (like meetings, deadlines, or resources) at your workplace?
#
# Ai can be integrated with project management tools, can automatically schedule your meetings and ping you about approaching deadlines accordingly, and can be used for task prioritization and resource allocation.

# %% [markdown]
# ### Exercises: Try It Yourself ❗
#
# ### Exercise 1: Speaker-based Minutes
#
# Take a sample transcript (or your last meeting notes) and prompt AI:
#
# ```
# Summarize the meeting into minutes by speaker.
# Add 2–3 bullet points per speaker, and mark action items clearly.
# ```
#
# ```
# CTAS County Commission – Meeting Minutes (Condensed)
#
# Chairman Wormsley
#
# Called meeting to order, confirmed quorum, approved agenda and minutes.
#
# Announced next meeting: Monday, August 19 at 7 p.m.
#
# Commissioner McCroskey
#
# Noted omission from Special Committee on Indigent Care.
# Action: Clerk to update minutes.
#
# Commissioner Adkins
#
# Approved resolution transferring funds to purchase a laptop.
#
# Moved wheel tax increase by $10 to cover state education cuts; passed 17-2.
#
# Commissioner Rodgers
#
# Moved to increase state match local litigation taxes; provided data.
#
# Commissioner Duckett
#
# Proposed amendment: 25% of increased criminal case taxes go to sheriff; amendment passed 17-2.
#
# Voting on Litigation Tax Resolution
#
# Amended motion failed (tie vote 9-9-1).
#
# Commissioners Thompson & Carmical
#
# Seconded wheel tax resolution and previous question motions.
#
# Commissioner Hayes
#
# Moved previous question on wheel tax increase; passed 17-2.
#
# Commissioner Hailey
#
# Announced Budget Committee meeting: July 16 at noon.
#
# Commissioner Carmical
#
# Announced chili supper: August 16 at 6:30 p.m.
#
# Commissioner Austin & Garland
#
# Moved and seconded adjournment; meeting adjourned.
#
# Key Action Items:
#
# Clerk to update minutes with Commissioner McCroskey’s committee assignment.
#
# Laptop purchase resolution approved.
#
# Litigation tax increase resolution (amended) failed.
#
# Wheel tax increase passed (17-2).
#
# Attend Budget Committee meeting on July 16 if applicable.
# ```
#
# ### Exercise 2: Action-Focused Notes
#
# Use this prompt:
#
# ```
# Create meeting minutes that focus only on action items.
# Format each entry as: Action Item, Responsible Person, Deadline.
# ```
# ![image.png](data:image/png;base64,...)
#
# ### Exercise 3: Thematic Notes
#
# Try refining for themes:
#
# ```
# Group meeting minutes into sections based on topics discussed.
# For each section, summarize key decisions, and list assigned action items.
# ```
#
# ```
# 1. Opening & Administrative Business
#
# Discussion:
#
# Meeting called to order by Chairman Wormsley.
#
# Agenda approved unanimously.
#
# Minutes from last meeting corrected to add Commissioner McCroskey’s name to Special Committee on Indigent Care, then approved.
#
# Key Decisions:
#
# Agenda adopted.
#
# Minutes approved with correction.
#
# Action Items:
#
# Clerk to update minutes with Commissioner McCroskey’s name.
#
# 2. Resolution: Laptop Purchase
#
# Discussion:
#
# Commissioner Adkins moved to transfer funds from Data Processing Reserve to purchase a laptop.
#
# Motion seconded and approved.
#
# Key Decision:
#
# Resolution to purchase laptop passed.
#
# Action Items:
#
# Clerk to record resolution approval.
#
# Funds to be moved as per resolution.
#
# 3. Old Business: Property Sale Near Airport
#
# Discussion:
#
# Commissioner McKee withdrew prior motion to sell airport property.
#
# No objections.
#
# Key Decision:
#
# Motion to sell airport property withdrawn.
#
# Action Items:
#
# None.
#
# 4. Resolution: Increase Litigation Tax
#
# Discussion:
#
# Commissioner Rodgers introduced resolution to increase state match local litigation tax.
#
# Commissioner Reinhart seconded (for discussion).
#
# Commissioner Duckett moved amendment: allocate 25% of criminal case proceeds to Sheriff’s Dept. Amendment seconded and approved (17–2).
#
# Roll call vote held on amended resolution: 9 in favor, 9 opposed, 1 not voting.
#
# Key Decisions:
#
# Amendment requiring 25% to Sheriff’s Dept passed.
#
# Final resolution (as amended) failed due to tie.
#
# Action Items:
#
# None (since resolution failed).
#
# 5. Resolution: Wheel Tax Increase ($10)
#
# Discussion:
#
# Commissioner Adkins moved to raise wheel tax by $10 to offset education funding cuts.
#
# Motion seconded.
#
# Debate followed.
#
# “Previous Question” motion passed (17–2), cutting off debate.
#
# Vote on resolution: Passed (17–2) on first reading.
#
# Key Decision:
#
# Wheel tax increase of $10 approved on first passage.
#
# Action Items:
#
# Resolution to proceed to next required readings.
#
# 6. Announcements
#
# Budget Committee meeting on July 16 at noon (solid waste funding).
#
# Next County Commission meeting: August 19 at 7 p.m.
#
# Community chili supper: August 16 at 6:30 p.m. at County Elementary School.
#
# Action Items:
#
# Commissioners to attend Budget Committee meeting.
#
# Clerk to schedule next meeting.
#
# 7. Adjournment
#
# Motion to adjourn approved without objection.
#
# Key Decision:
#
# Meeting adjourned.
#
# Action Items:
#
# None.
# ```

# %% [markdown]
# ### ✅ Reflection Question 💡
#
# How could AI-generated meeting notes help you **improve follow-up and accountability** in your workplace?
#
# attending a meeting and noting important is a hectic times and most of the time you miss a point usually. hence, AI tools play an important role here, that helps you transcribe the meeting and note keypoints as well

# %% [markdown]
# ## Exercises: Try It Yourself ❗
#
# ### Exercise 1: Outline Summary
#
# Take a long article or report. Prompt AI:
#
# ```
# Summarize this document into a bulleted outline of no more than 10 points.
# ```
# ```
# Purpose: Provides a systematic literature review (SLR) on vulnerabilities, mitigation techniques, and attacks in Field-Programmable Gate Arrays (FPGAs).
#
# FPGA Significance: Highlights FPGAs’ widespread adoption due to flexibility, performance, and cost benefits, while noting their increasing exposure to security threats.
#
# Types of Vulnerabilities: Identifies key vulnerabilities in FPGA systems, including side-channel leaks, hardware Trojans, bitstream attacks, and denial-of-service.
#
# Attack Categories: Reviews physical, side-channel, and remote attacks, discussing their methods and impact on FPGA security.
#
# Mitigation Techniques: Explores countermeasures such as bitstream encryption, obfuscation, access control, fault detection, and side-channel resistance methods.
#
# Research Trends: Notes a growing focus on AI/ML-assisted security, lightweight cryptography, and reconfigurable hardware defenses.
#
# Challenges: Points out trade-offs between security, performance, power consumption, and cost when designing countermeasures.
#
# Evaluation Methods: Summarizes approaches used to assess FPGA security (e.g., simulations, prototypes, case studies).
#
# Research Gaps: Identifies need for standardized benchmarks, comprehensive testing frameworks, and practical deployment strategies.
#
# Conclusion: Calls for holistic, multi-layered defense strategies and future work on integrating FPGA security into real-world applications.
# ```
#
# ### Exercise 2: Audience Summary
#
# Try this with the same text:
#
# ```
# Summarize this document as if explaining it to a high school student.
# ```
#
# ```
# The paper talks about a type of computer chip called Field-Programmable Gate Arrays (FPGAs). These are special chips that can be programmed to do many different jobs after they’re made, which makes them flexible and useful in things like phones, cars, and even space technology.
#
# But since they are so flexible, they can also be attacked by hackers in different ways. The paper reviews what kinds of security problems (vulnerabilities) exist in FPGAs, what kinds of attacks can happen, and what kinds of solutions (mitigation techniques) people have created to protect them.
#
# The main points are:
#
# FPGAs are powerful but can be targeted by attacks like side-channel attacks (stealing information from power or timing signals), hardware Trojans (hidden malicious circuits), or configuration memory attacks.
#
# Researchers have proposed different ways to defend against these problems, such as encryption, randomization, and extra monitoring systems.
#
# The paper compares these techniques to see which ones work best and where improvements are still needed.
#
# 👉 In short: FPGAs are like customizable computer chips, but because they’re so flexible, they’re also more open to being hacked. Scientists are studying different ways to keep them safe.
# ```
#
# ### Exercise 3: Comparative Summary
#
# Use:
#
# ```
# Summarize this report in two versions:
# 1. Executive summary for leadership.
# 2. Simplified version for frontline employees.
# ```
#
# ```
# 1. Executive Summary for Leadership
#
# This systematic literature review examines vulnerabilities, attacks, and mitigation strategies in Field Programmable Gate Arrays (FPGAs). The study identifies a broad spectrum of security threats—ranging from hardware Trojans and side-channel attacks to bitstream manipulation—highlighting the risks these pose to mission-critical systems. It emphasizes that while FPGAs offer flexibility and performance, they remain highly exposed to malicious exploitation without proactive defense. The review synthesizes mitigation techniques, including hardware-level protections, encryption, obfuscation, and runtime monitoring. Key insights show that layered, adaptive security strategies are most effective. For leadership, the report underscores the urgent need for investment in FPGA security research, adoption of standardized security frameworks, and strategic allocation of resources to safeguard national security, critical infrastructure, and enterprise systems.
#
# 2. Simplified Version for Frontline Employees
#
# This report looks at how FPGAs—special chips used in many technologies—can be attacked and how we can protect them. Hackers can try tricks like planting hidden code, stealing information through power use, or changing the chip’s instructions. The good news is there are defenses: we can encrypt data, hide design details, and use monitoring systems to catch unusual activity. The key takeaway is that no single solution is enough—combining multiple protections works best. For you, this means staying alert to potential risks and following the security practices we put in place to keep our systems safe.
# ```

# %% [markdown]
# ## ✅ Reflection Question 💡
#
# How could tailoring summaries to **different audiences** (executives, clients, students) improve understanding and decision-making in your work?
#
# tailoring summaries to different audiecnes definitely help the audience understand int he kind of language that they can interpret very easily

# %% [markdown]
# ## Exercise
#
# 1. Take a long article or report.
# 2. Summarize it in 3 steps:
#
#    * Broad overview (1 paragraph)
#    * Shorter summary (3 bullet points)
#    * Single sentence (main trend/insight).
#
# ```
# 1. Broad Overview (1 paragraph)
#
# The literature review provides a comprehensive analysis of vulnerabilities in Field-Programmable Gate Arrays (FPGAs), focusing on how attackers exploit hardware features such as configuration bits, side channels, and supply chains. It categorizes common attack vectors—like side-channel attacks, hardware Trojans, and fault injection—and evaluates existing mitigation techniques, including bitstream encryption, redundancy, obfuscation, and design-time security frameworks. The study highlights gaps in current defenses, noting that many countermeasures are either application-specific or impose high performance costs. The review emphasizes the need for more holistic, lightweight, and adaptive approaches to securing FPGAs as they become increasingly important in critical systems.
#
# 2. Shorter Summary (3 bullet points)
#
# FPGAs face multiple attack vectors: side-channel leaks, hardware Trojans, and fault injection.
#
# Current mitigations (encryption, redundancy, obfuscation) help but often add overhead or lack universality.
#
# Future research should focus on scalable, lightweight, and adaptive security solutions.
#
# 3. Single Sentence (Main Trend/Insight)
#
# FPGA security research is shifting toward finding balanced, adaptable defenses that protect against diverse attacks without sacrificing performance.
# ```

# %% [markdown]
# # 3. Use AI as a creative or expert partner

# %% [markdown]
# ### 📝 Questions for Reflection
#
# 1. How is prompt chaining similar to solving a jigsaw puzzle?
#
# Answer: It's similar to a jigsaw puzzle as each prompt is a little chunk or piece of solving the complex problem.
#
# 2. What’s the main difference between **iteration** and **chaining**?
#
# Answer: Iteration is refining a one big single prompt, whereas chaining is all the prompts are linked to each other, completing one big picture together.
#
# 3. Why might prompt chaining be more effective than asking AI one big question?
#
# Answer: as it breaks the task into manageable small chunks.
#
# 4. How can the **context window** of an AI model affect your chaining strategy?
#
# Answer: context window is basically the memory model of an AI, how much past info can the AI remember to answer your question. if the context window is quite small (e.g: it remembers only the last five msgs), then you'd have to mould your chaining prompts accordingly.

# %% [markdown]
# ##  Exercises : Try It Yourself ❗
#
# ### Exercise 1: Email Catch-Up
#
# Imagine you were away from work for a week. Create a **prompt chain** that does the following:
#
# 1. Summarizes all your emails.
#
#
# > Help me understand all of these emails in bullets, each bullet for one email. [paste all emails]
#
#
# 2. Highlights urgent tasks.
#
#
# > highlight the ones that are urgent/high priority
#
#
# 3. Suggests solutions for the most critical issue.
#
#
#
# > out of all the emails, [most critical email] give me a solution of this
#
#
#
# ### Exercise 2: Research Assistant
#
# You’re writing a research paper. Design a chain of prompts to:
#
# 1. Generate an outline of your paper.
#
#
# > this is the research paper i am working on, [paste research paper], excerpt an outlined version of this
#
#
# 2. Suggest three key studies you should cite.
#
#
# > let me know three key studies that i should cite in my research paper
#
#
# 3. Draft a short introduction based on the outline and studies.
#
#
# > draft a short intro for me based on the prior outline and studies that u just cited
#
#
#
# ### Exercise 3: Business Idea Pitch
#
# Pretend you want to launch a new mobile app. Build a prompt chain that:
#
# 1. Creates a one-sentence pitch.
#
#
# > i am creating a new mobile app, this is my idea [paste idea here], create a catchy one sentence long pitch for me that grabs people's attention
#
#
# 2. Expands it into a short paragraph describing the target audience.
#
#
# > now expand this into a short paragraph and also add the target audience which is for [teens/adults etc]
#
#
# 3. Generates a three-slide pitch deck outline for investors.
#
#
# > using the one liner pitch and the short paragraph, generate a 3 slide pitch deck outline for the investors, making sure it grabs their attention so that i can secure funding and support from them

# %% [markdown]
# ### Exercise: Try It Yourself ❗
# 1. Think of a **complex decision** (e.g., project planning, resource allocation).
#
# Answer: choosing a career path
#
# 2. Write a prompt asking AI to solve it with **step-by-step reasoning**.
#    - Example: *“Help me allocate a $10,000 marketing budget across three channels. Explain your reasoning step-by-step.”*
#
#    Answer: Help me choose a career path between AI and Hardware Engineering, giving a step by step procedure on what do they do and what prep should i be doing etc
#
# 3. Review the output and tweak the prompt if needed (e.g., add constraints like time or audience).

# %% [markdown]
# ### Exercise: Try It Yourself ❗
# 1. Pick a **creative or abstract problem** (e.g., designing a campaign, brainstorming product features).
#
# Answer: designing a floor plan for the house
#
# 2. Write a prompt asking AI to explore **multiple solutions** and evaluate them.
#    - Example: *“Propose three marketing strategies for a new app launch. Evaluate each for cost, reach, and impact.”*
#
#    Answer: propose a design floor plan for the house, [add details of the house and dimensions]
#
# 3. Review the output and iterate to refine (e.g., focus on one path or add constraints).

# %% [markdown]
# ## **Practice Advanced Prompting Techniques**
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: CoT for Decision-Making
# Write a prompt for a work-related decision (e.g., prioritizing tasks, choosing vendors). Ask AI to explain its reasoning step-by-step.
# Example: *“Help me choose between two software vendors. Explain your reasoning for each step.”*
#
# Answer: i have two tasks at hand: one is to write an email to professor and one is solve a jupyter notebook questions of my fellowship regarding AI
# help me choose between the two, which one to prioritize first. explain its reasoning step-by-step
#
# #### Exercise 2: ToT for Creative Brainstorming
# Write a prompt for a creative task (e.g., campaign ideas, product features). Ask AI to propose multiple solutions and evaluate them.
# Example: *“Suggest three themes for a company retreat. Evaluate each for engagement and cost.”*
#
# #### Exercise 3: Combine CoT and ToT
# Write a prompt that uses ToT to explore options and CoT to refine the best one.
# Example: *“Propose three product launch ideas, evaluate them, then provide a step-by-step plan for the best one.”*
#
# Answer: i want to create a project in my AI fellowship, propose three ideas to me, evaluate them in terms of doabiliy and difficulty and give me a breakdown of steps for the best one overall.
#
# ### ✅ Reflection Question 💡
# How could CoT and ToT prompting help you **solve complex problems** or **spark creativity** in your workplace?
#
# Answer: CoT helps in breaking down steps which helps in solving complex problems by breaking them down into smaller doable chunks, and ToT helps in exlporing multiple pathways in one topic which definitely help spark the creativity even more.

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **complex project** (e.g., product launch, training program).
#
# creating an AI for health app
#
# 2. Write a ToT prompt to explore three options.
#
# using the principles of ToT, help me explore multiple options in creating an AI for health app
#
#
# 3. Write a CoT prompt to refine the best option with step-by-step reasoning.
#
# from the aforementioned options, choose one of the best options and tell me why are you choosing this option by breaking down your reasoning and the outline of the project in steps

# %% [markdown]
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Build a Project Step-by-Step
# 1. Pick a multi-step project (e.g., marketing campaign, event planning).
#
# planning an AI club event at my university
#
# 2. Chain three prompts: outline, expand a section, create an activity/visual.
#    - Example: *“Outline a team training program, expand one module, suggest an interactive exercise.”*
#
#    help me outline a schedule for the event, focus on one scheduled event and suggest an activity that can be done in an onsite event
#
# #### Exercise 2: CoT for Clarity
# 1. Choose a task requiring logic (e.g., budgeting, scheduling).
#
# a math word problem
#
# 2. Prompt AI to explain its reasoning step-by-step.
#    - Example: *“Allocate a $2,000 budget for a team event. Explain your reasoning.”*
#
# Adrianna has 10 pieces of gum to share with her friends. There wasn’t enough gum for all her friends, so she went to the store and got 70 pieces of strawberry gum and 10 pieces of bubble gum. How many pieces of gum does Adrianna have now? explain your answer with reasoning step by step
#
# #### Exercise 3: ToT for Creativity
# 1. Pick a creative task (e.g., branding, content ideas).
#
# content idea for my next youtube video
#
# 2. Prompt AI to propose three solutions and evaluate them.
#    - Example: *“Suggest three social media campaign ideas. Evaluate each for engagement.”*
#
#    i am a gamer who records videos on the youtube platform, suggest me three new content ideas that might increase my followers and my views
#
# #### Exercise 4: Combine CoT and ToT
# 1. Use ToT to explore options for a project.
#
# i want to create a project on AI in energy systems area, give me good options regarding this that i can add in my profile to impress a professor
#
# 2. Use CoT to refine the best option with detailed reasoning.
#    - Example: *“Propose three event formats, evaluate them, then plan the best one with step-by-step reasoning.”*
#
#    from the above mentioned projects choose the best one in terms of doability and difficulty and tell me step by step the reasoning and then plan the entire project
#
# ### ✅ Reflection Question 💡
# How could prompt chaining help you **simplify a complex project** or **improve collaboration** in your workplace?
#
# prompt chaining simplifies the project by breaking into doable chunks and improves collaboration as all those small structured chunks can be divided into people accordingly

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **large document** (e.g., report, manuscript, or presentation).
# 2. Write a prompt asking AI to analyze it for key points, gaps, or improvements.
#    - Example: *“Analyze my 50-page report and summarize the main arguments in bullet points.”*
#
# this is a professor's research work, i want you to analyse it for keypoints and gaps and improvements
#
# 3. Review the output and refine the prompt (e.g., ask for specific feedback on tone or structure).

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Pick a **time-sensitive task** (e.g., email, proposal, or presentation).
#
# an email to a uni professor
#
# 2. Write a prompt asking AI to draft an outline or initial version.
#    - Example: *“Draft a professional email inviting clients to a product demo. Include date, time, and purpose.”*
#
#    i want to email a professor outlining my profile and interest in his research area, draft an outline or an initial version of an email
#
# 3. Refine the output to match your style or add specific details.

# %% [markdown]
# ## **Practice Using AI as Your Thought Partner**
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Analyze a Document
# 1. Choose a **long document** (e.g., report, article, or draft).
# 2. Prompt AI to summarize or critique it.
#    - Example: *“Summarize this 20-page report in 5 bullet points, focusing on key findings.”*
#
#    this is a 90 page long research worok of my own, this is my fyp report. summarize and critique on it
#
# #### Exercise 2: Draft for a Deadline
# 1. Pick an **urgent task** (e.g., email, proposal, or plan).
#
# an fyp proposal
#
# 2. Prompt AI to create a draft or outline.
#    - Example: *“Draft a 200-word project summary for a client meeting tomorrow.”*
#
#    i have my fyp proposal due tomorrow can you please help me write a 250 characters long abstract
#
# #### Exercise 3: Brainstorm Ideas
# 1. Choose a **creative challenge** (e.g., product feature, campaign idea).
#
# an mango themed event idea for my teammates
#
# 2. Prompt AI to suggest three ideas and explain their value.
#    - Example: *“Propose three event ideas for a team retreat and explain their benefits.”*
#
# i want to host a mango themed event as it is mango season in pakistan, event will be organised at my workplace and i need ideas on what activities i can arrange related to the theme
#
# #### Exercise 4: Combine Analysis and Drafting
# 1. Use AI to analyze a document, then draft a related output.
#    - Example: *“Analyze this report for key trends, then draft a 100-word summary for executives.”*
#
# analyse this article regarding body shaming and draft a 250 character long summary or an outline on what's going on here
#
# ### ✅ Reflection Question 💡
# How could enlisting AI as a thought partner help you **save time**, **spark creativity**, or **improve decision-making** in your workplace?
#
# Ai helps save time in workplace by automating repititive tasks or doing the basic tasks itself, sparks creativity if you know the niche you want to work in and helps generating creative ideas, and finally it improves decision making by giving an overall step by step breakdown on how to approach a problem systematically

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Pick a **task** (e.g., email, plan, or creative brief).
#
# an email to a professor
#
# 2. Write a meta-prompt asking AI to generate a prompt for it.
#    - Example: *“Generate a prompt to write a thank-you email to event attendees.”*
#
#    generate a meta prompt of this:   i want to email a professor outlining my profile and interest in his research area, draft an outline or an initial version of an email
#
#    "Act as a professional academic email assistant. I want to contact a professor to express interest in their research and highlight my background. Generate an outline or initial draft of a concise, respectful, and compelling email that introduces my profile, connects my recent projects to the professor’s work, and communicates my eagerness to collaborate."

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **structured task** (e.g., project plan, meeting agenda).
#
# an fyp project timeline
#
# 2. Write a meta-prompt for a prompt template.
#    - Example: *“Create a template for a prompt to plan a product launch timeline.”*
#
#    generate a meta prompt: generate a template for a prompt an fyp project timeline
#
#    "Act as a project planning assistant. Generate a template prompt that I can use to create an FYP (Final Year Project) timeline. The template should include key phases (research, design, development, testing, documentation, presentation), deadlines, and milestones, while allowing customization for different project types."

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Find an **image** (e.g., artwork, photo) relevant to a task.
#
#
#
# 2. Write a meta-prompt to generate a prompt based on it.
#    - Example: *“Generate a prompt to create a poster inspired by this attached cityscape photo.”*
#
#    generate a prompt to create an attractive geography lesson related to this image of a map of canada
#
#    "Act as a creative geography teacher. Using this map of Canada, design an engaging lesson that introduces students to Canada’s provinces and territories. Include interactive elements (like quizzes, map-labeling activities, or fun facts), highlight key cities and landmarks, and connect geography to culture and history to make the lesson both educational and attractive."

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **text document** (e.g., article, manual).
# 2. Write a meta-prompt to generate a prompt based on it.
#    - Example: *“Using this attached report, generate a prompt to summarize its key findings.”*
#
#    using this article, tell me the key findings of this article related to the recent pakistan's political situations

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Pick a **complex task** (e.g., proposal, campaign plan).
#
# an fyp proposal
#
# 2. Write a meta-prompt to generate a prompt for one part, then chain another for the next part.
#    - Example: *“Generate a prompt for a campaign tagline, then one for a campaign timeline.”*
#
#    generate a prompt for fyp abstract, generate a prompt for fyp timeline

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose an **existing prompt** that gave lackluster results.
# 2. Write a meta-prompt to improve it.
#    - Example: *“How can I make this prompt for a team email more engaging? [Attach prompt]”*
#
#
#    "Act as a professional academic email assistant. I want to contact a professor to express interest in their research and highlight my background. Generate an outline or initial draft of a concise, respectful, and compelling email that introduces my profile, connects my recent projects to the professor’s work, and communicates my eagerness to collaborate." how can make this prompt even more 'to the point' that it generates an email that hits the spot on everything i need in this email to the professor?

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Gather **2–3 prompts** for the same task that didn’t work well.
# 2. Write a meta-prompt to combine them into one.
#    - Example: *“Combine these prompts for a meeting agenda into one clear prompt. [Attach prompts]”*
#
#
#    "Act as a professional academic email assistant. I want to contact a professor to express interest in their research and highlight my background. Generate an outline or initial draft of a concise, respectful, and compelling email that introduces my profile, connects my recent projects to the professor’s work, and communicates my eagerness to collaborate."
#
#    "add about my research topics being ai in health"
#
#    "add the professor's details and everything mentioned here in his profile [profile]"
#
#    combine all of these prompts and then generate an email related to this

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **prompt** with bland or off-tone results.
# 2. Write a meta-prompt to rewrite it with a specific tone or style.
#    - Example: *“Rewrite this prompt for a product description to be more fun and engaging. [Attach prompt]”*
#
#    generate a prompt to create an attractive geography lesson related to this image of a map of canada.
#    rewrite this prompt to add in [details]

# %% [markdown]
# ## **Practice Meta-Prompting**
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Direct Generation
# 1. Pick a **task** (e.g., writing, planning, or design).
#
# writing
#
# 2. Write a meta-prompt to generate a prompt for it.
#    - Example: *“Generate a prompt to write a customer thank-you email for a retail store.”*
#
#    generate a prompt to write a childrens book story for a 2 year old infant
#
# #### Exercise 2: Template Request
# 1. Choose a **structured task** (e.g., event plan, report outline).
# 2. Write a meta-prompt for a prompt template.
#    - Example: *“Create a template for a prompt to organize a team-building event.”*
#
#    generate a prompt to organize an onsite AI event at my university and i want a detailed timeline and schedule which i can follow
#
# #### Exercise 3: Prompt Refinement
# 1. Take an **existing prompt** with suboptimal results.
# 2. Write a meta-prompt to improve its tone, clarity, or specificity.
#    - Example: *“How can I improve this prompt for a social media post to be more engaging? [Attach prompt]”*
#
#    how can i make this prompt for a linkedin post make it more eye catchy for my linkedin viewers? write a linkedin post about my graduation with a distinction and receiving a rank in top 25 students in my batch of 152 students
#
# #### Exercise 4: Meta-Prompt Chaining
# 1. Choose a **complex task** (e.g., proposal, campaign).
# 2. Write a meta-prompt for one part, then chain another for the next part.
#    - Example: *“Generate a prompt for a campaign slogan, then one for a campaign timeline.”*
#
#    geenrate a prompt for a Ai event onsite. generate a prompt for team responsibilities as well
#
# ### ✅ Reflection Question 💡
# How could meta-prompting help you **craft better prompts** or **improve AI outputs** for your specific work tasks?
#
# it structures the prompts properly which yields out better AI outputs

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Write a **meta-prompt** to generate or refine a prompt for AgentSim or AgentX.
#    - Example: *“Generate a prompt for an AI agent to simulate a team meeting discussion on project priorities.”*
#
# generate a prompt for the AI agent to simulate a team meeting discussion on event preparations
#
# 2. Test the generated prompt and refine it if needed.

# %% [markdown]
# ## **Practice Building AI Agents**
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Create AgentSim
# 1. Choose a **scenario** (e.g., job interview, client pitch).
#
# taking a job interview of a candidate
#
# 2. Write a prompt for AgentSim to role-play, including a stop phrase and feedback.
#    - Example: *“Act as a client in a product demo. Discuss features and pricing. End when I say ‘THANKS.’ Provide feedback.”*
#
#    act as a job interviewer, i will be your potential candidate. ask me role relevant questions but make sure they're not too hard but they're trick, just enough for you to understand that i am ready for this role or no. end when i say 'good bye', and provide feedback to my shortcomings.
#
# #### Exercise 2: Create AgentX
# 1. Pick a **work output** (e.g., code, design, or plan).
#
# code
#
# 2. Write a prompt for AgentX to provide expert feedback.
#    - Example: *“Act as a UX design expert. Review my app prototype and suggest improvements for usability.”*
#
#    act as an ai engineer with 5 years of experience, review my rag based app that i have created and give feedback accordingly.
#
# #### Exercise 3: Use Meta-Prompting
# 1. Write a meta-prompt to generate or refine a prompt for AgentSim or AgentX.
#    - Example: *“Generate a prompt for an AI agent to simulate a performance review discussion.”*
#
#    generate a prompt for an ai agent to act as an ai engineer and critique on my work
#
# #### Exercise 4: Combine Simulation and Feedback
# 1. Use AgentSim to practice a scenario, then AgentX to review your performance.
#    - Example: *“Simulate a client meeting, then provide feedback as a sales coach.”*
#
#    simulate a job interview, then give feedback as an HR executive
#
# ### ✅ Reflection Question 💡
# How could AI agents like AgentSim and AgentX help you **practice skills** or **improve work outputs** in your role?
#
# they help you practice by simulating the environment at your own comfort and improving work efforts by acting as an expert and giving helpful feedback

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **work output** (e.g., pitch, report, or design).
# 2. Write a prompt for AgentX to critique it, specifying the persona, focus areas, and a stop phrase.
#    - Example: *“Act as a marketing executive. Review my ad campaign draft, focusing on messaging and visuals. Continue until I say ‘DONE.’ Provide a summary afterward.”*
#
#    "You are a professional productivity coach. Help me navigate with my lifestyle and critique on how productive i truly am. Suggest improvements where needed. Stop after i say STOP."
#
# 3. Test the feedback and refine the prompt for more specificity if needed.

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Write a **meta-prompt** to generate or refine a prompt for AgentX.
#    - Example: *“Generate a prompt for AgentX to critique a website design as a UX expert.”*
#
#    generate a prompt for agentx to critique on my data analysis project as a data analyst expert level
#
# 2. Test the generated prompt and refine it if needed.

# %% [markdown]
# ## **Practice Building AgentX**
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Create AgentX for Feedback
# 1. Choose a **work output** (e.g., proposal, design, or code).
#
# code
#
# 2. Write a prompt for AgentX to critique it, specifying the persona and focus areas.
#    - Example: *“Act as a content strategist. Review my blog post draft for clarity and engagement. Continue until I say ‘FINISH.’ Provide a summary.”*
#
#    act as a person who has solved more than 2000 leetcode questions. review my coding strategies and give feedback on where am i wrong and how can i be better. continue until i say 'finish'.
#
# #### Exercise 2: Refine with Meta-Prompting
# 1. Take a **vague prompt** for AgentX that didn’t work well.
#
# Give me a good book recommendation
#
# 2. Write a meta-prompt to improve it.
#    - Example: *“How can I improve this prompt to get better feedback on my marketing plan? [Attach prompt]”*
#
#    how can i improve this prompt for it to suggest me the kind of books i like? [Give me a good book recommendation]
#
# #### Exercise 3: Use Context for Feedback
# 1. Attach or describe a **specific document** (e.g., brief, draft).
#
# fyp draft
#
# 2. Write a prompt for AgentX to critique it using the context.
#    - Example: *“Act as a client. Review my attached campaign brief for appeal and clarity. Continue until I say ‘DONE.’ Summarize feedback.”*
#
#    act as my fyp coordinator. review my fyp draft and give me feedback and suggest me better ideas (if my idea is not nice). continue until i say 'done'.
#
# #### Exercise 4: Iterate Feedback
# 1. Use AgentX to critique a draft, revise it, then ask AgentX to review the revised version.
#    - Example: *“Review my revised pitch after incorporating your earlier feedback. [Attach revised pitch]”*
#
#    review my fyp draft again after adding your changes into it
#
# ### ✅ Reflection Question 💡
# How could AgentX’s expert feedback help you **improve specific work outputs** or **prepare for high-stakes scenarios** in your role?
#
# agentx can improve my work outputs by acting as an expert and give me suggestions based on it and prepare me for high stake scenarios by critiquing on everything

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **skill** to practice (e.g., public speaking, sales pitching).
#
# public speaking
#
# 2. Write a prompt for an AI agent to role-play and provide feedback.
#    - Example: *“Act as a public speaking coach. Role-play an audience Q&A session and critique my responses. End with ‘CURTAIN CALL.’”*
#
#    act as a public speaking mentor and help me practice public speaking for my upcoming sessions, note my body language and my tone and everything that's not okay. end it when i say 'stop'

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **new skill or topic** (e.g., coding, marketing).
#
# coding
#
# 2. Write a prompt for an AI agent to teach it with lessons and feedback.
#    - Example: *“Act as a Python tutor. Teach me basic coding with exercises. End with ‘CODE OFF.’”*
#
#    act as a data science tutor, and critique on my uploaded projects that i have created uptil now and how can i make it better

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Choose a **project task** (e.g., campaign plan, research report).
#
# research report
#
# 2. Write a prompt for an AI agent to collaborate on it.
#    - Example: *“Act as a marketing strategist. Help me draft a campaign plan. End with ‘FINISHED.’”*
#
#    act as a professor supervising research students for a very long time and critique on my research methodologies, give me strategies to help and give me feedback on how to become a better researcher. end it when i say 'stop'.

# %% [markdown]
# ## **Practice Building AI Agents**
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Skill Practice Agent
# 1. Choose a **skill** (e.g., negotiation, presenting).
#
# presenting
#
# 2. Write a prompt for an AI agent to role-play and provide feedback.
#    - Example: *“Act as a sales coach. Role-play a client pitch and critique my performance. End with ‘SOLD.’”*
#
#    act as a expert presenter, help me give points that can make me a good presenter overall, and strategies to be more confident with my presenting skills overall. stop it when i say 'stop'.
#
# #### Exercise 2: Feedback Agent
# 1. Pick a **work output** (e.g., writing, design).
#
# writing a research proposal
#
# 2. Write a prompt for an AI agent to critique it.
#    - Example: *“Act as an editor. Critique my article for clarity and tone. End with ‘PUBLISH.’”*
#
#    act as an expert researcher. critique on my research methods and my current work i am working on overall. stop it when i say 'stop'.
#
# #### Exercise 3: Learning Agent
# 1. Choose a **new skill or topic** (e.g., language, software).
#
# language learning
#
# 2. Write a prompt for an AI agent to teach it with lessons and quizzes.
#    - Example: *“Act as a data analysis tutor. Teach me Excel basics with exercises. End with ‘LESSON OVER.’”*
#
#    act as a french teacher. help me teach basic french and give feedback on how am i speaking/writing. end it when i say 'stop'.
#
# #### Exercise 4: Collaboration Agent
# 1. Pick a **project task** (e.g., proposal, plan).
#
# research proposal
#
# 2. Write a prompt for an AI agent to collaborate on it.
#    - Example: *“Act as a project manager. Help me draft a project timeline. End with ‘COMPLETE.’”*
#
#    act as a teammate in a project. help me draft this research proposal for my fyp. end with 'stop'.
#
# ### ✅ Reflection Question 💡
# How could AI agents help you **tackle specific challenges** or **achieve goals** in your work or personal life?
#
# ai helps in tackling and achieving specific tasks in work or personal by acting as an expert and giving constructive feedback accordingly

# %% [markdown]
# #### Exercise: Try It Yourself ❗
# 1. Pick a **task** for your library (e.g., email, report, plan).
#
# email
#
# 2. Write a meta-prompt to generate or refine a prompt for it.
#    - Example: *“Generate a prompt for a team meeting agenda with a professional tone.”*
#
#    generate a prompt for emailing a professor to impress him by showing my skills and profile
#
# 3. Add the prompt to your library with version notes.

# %% [markdown]
# ## **Practice Building Your Prompt Library**
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Create a Communication Prompt
# 1. Choose a **communication task** (e.g., email, announcement).
#
# announcement of holiday
#
# 2. Write a prompt and save two versions (e.g., formal vs. casual).
#    - Example: *“Write a customer email for a product recall (v1: formal, v2: empathetic).”*
#
#    write a holiday announcement on the occasion of 14th august tomorrow for my office (v1: witty and funny, v2: strictly business)
#
# #### Exercise 2: Create a Content Prompt
# 1. Pick a **content task** (e.g., FAQ, social media post).
#
# linkedin post
#
# 2. Write a prompt and version it for different audiences.
#    - Example: *“Create 5 FAQs for consumers (v1) and businesses (v2) based on this product.”*
#
#    create a linkedin post on my graduation with distinction with funny jokes of surviving university barely (v1) and mentioning my achievements and my extra curricular activities (v2)
#
# #### Exercise 3: Use Meta-Prompting
# 1. Write a meta-prompt to generate or refine a prompt for your library.
#    - Example: *“Generate a prompt for a project status report with a clear, professional tone.”*
#
#    geenrate a prompt for a social media post with a funny tone and good jokes
#
# #### Exercise 4: Organize Your Library
# 1. Create a **spreadsheet or document** with 3–5 prompts, categorized by use case.
# 2. Add notes on tone, audience, and effectiveness.
#
# ### ✅ Reflection Question 💡
# How could a prompt library help you **streamline repetitive tasks** or **improve AI outputs** in your work?
#
# a prompt library honestly feels like a lifesaver. instead of wasting time retyping the same stuff, I could just reuse solid prompts for all the repetitive tasks. plus, it makes my ai outputs way better because the responses are actually useful.

# %% [markdown]
# # 📚 Chatbot Development Project – Guideline

# %% [markdown]
# ### 1. Choose a Use Case
# Pick a real-world problem that a chatbot can solve.
#
# **My pick: IELTS W study buddy**
#
# What to do:
#
# Write a **short paragraph** explaining why you chose this use case.
#
# I picked an IELTS study buddy because it’s simple to build fast and actually helps people hit a real goal. It’s stuff I already know (prompts, rubrics, practice tasks), so I can put out a useful MVP quickly, with timed writing tasks with feedback, and then polish features from user feedback.
#
# Identify **target users** (who will use it) and **expected benefits**.
#
# Target users: Students and professionals preparing for IELTS (self-learners, coaching groups).
#
# Expected Benefits: instant writing feedback with improvement tips, personalized weekly study plan, confidence building before test day.
#
# List **limitations** (what it cannot do).
#
# - Not an official examiner, so it won’t guarantee band scores.
# - May sometimes give imperfect scoring/feedback (LLMs can be inconsistent).
# - Not a replacement for live coaching for complex pronunciation or high-stakes speaking nuance.

# %% [markdown]
# ### 2. Justify Your Choice
#
# Why is this problem worth solving with a chatbot?
#
# Answer: Preparing for IELTS can be overwhelming and expensive. A chatbot makes practice easier, affordable, and always accessible.
#
# How does a chatbot improve the experience compared to a website, app, or human support?
#
# Answer: Unlike websites or apps, it feels interactive and simulates real test conditions. It’s also 24/7 and more affordable than human tutors.
#
# What specific tasks will your chatbot perform?
#
# Answer: The chatbot will generate speaking prompts, give writing feedback, suggest study plans, and share grammar or strategy tips.

# %% [markdown]
# ### 3. Select the LLM
#
# - Research which Groq-supported model you want to use (e.g., llama3-8b, mixtral-8x7b).
# - Explain why this model fits your use case:
#     - I will use llama-3.1-8b-instant because it balances speed, cost, and performance. Since the chatbot needs to give quick feedback and generate prompts in real-time, a smaller and faster model is better than a very large one. It also supports English fluently, which fits the IELTS use case. Larger models like llama-3.3-70b-versatile or gpt-oss-120b are more powerful, but they are slower and more expensive, which isn’t necessary for this lightweight educational assistant.

# %% [markdown]
# ### 4. Design the Conversation Flow
# Before you write any code, plan how the chatbot will talk.
#
# Write **sample user inputs and expected responses.**
#
# ```
# User: “Hi”
# Bot: “Hello! I’m your IELTS Study Buddy. Want to practice Speaking, Writing, or get quick tips?”
#
# User: “Check my essay on climate change.”
# Bot: “Got it! Here’s your feedback: Band 6.5. Strength: good ideas. Improve: vocabulary variety and grammar accuracy.”
#
# User: “Help me with vocabulary for graphs.”
# Bot: “Here are some useful words for describing trends: increase, decline, plateau, fluctuate, soar.”
#
# ```
#
# Decide how your chatbot will handle:
#
# Unknown questions (fallback response).
#
# > “Hmm, I’m not sure about that. I can help with IELTS Writing, or study tips. Which would you like?”
#
# Greetings.
#
# > “Hi! I’m your IELTS W Study Buddy 🤝. Ready to practice and improve your score?”
#
# Goodbye.
#
# > “Good luck with your prep! 🌟 Come back anytime for more practice.”
#
# Context memory (should it remember previous messages?).
#
# > For simplicity, it won’t store long-term memory, but it can remember the current session (e.g., if a user says “give another feedback,” it knows they’re still talking about the same thing).

# %% [markdown]
# ### 5. Choose a Prompting Technique
# Prompting is how you tell the model what to do.
#
# What to do:
#
# 1. Clearly mention **which prompting technique(s) you used**.
#
# - **Few-shot prompting**: to show the model how to give structured feedback on essays or speaking responses.
#
# - **System prompt design**: to set the chatbot’s persona as a friendly, knowledgeable IELTS tutor.
#
# 2. Justify your choice — why was this the best method for your use case?
#
# > Few-shot prompting helps the model understand the exact format of feedback we want (band score, strengths, improvements). System prompts make the chatbot more engaging and consistent in tone, so users feel guided rather than just receiving raw instructions. This combination ensures feedback is accurate, actionable, and user-friendly.
#
# 3. Show a sample of your actual **prompt template** (system + user message).
#
# ```
# User Input
#    │
#    ▼
# [User types naturally]
# "Check my essay on climate change"
#    │
#    ▼
# Bot Prepends Few-Shot Examples
#    │
#    ▼
# [Bot sends to LLM]
# System Prompt: "You are a friendly IELTS tutor..."
# Few-Shot Examples:
# Example 1: essay + feedback
# Example 2: essay + feedback
# User Essay: "Check my essay on climate change"
#    │
#    ▼
# LLM Generates Response
#    │
#    ▼
# Bot Sends Feedback to User
# "Band 6.5. Strength: clear ideas. Improvement: grammar and vocabulary variety."
# ```

# %% [markdown]
# # [Chatbot Link](https://huggingface.co/spaces/safiaa02/IELTS-W-Study-Buddy)
